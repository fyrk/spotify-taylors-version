# %%
import json
import os
from dataclasses import dataclass, field

import spotify
from dotenv import load_dotenv

# %%
load_dotenv(".env.local")
SPOTIFY_CLIENT_ID = os.getenv("SPOTIFY_CLIENT_ID")
SPOTIFY_CLIENT_SECRET = os.getenv("SPOTIFY_CLIENT_SECRET")

# %%
client = spotify.Client(SPOTIFY_CLIENT_ID, SPOTIFY_CLIENT_SECRET)

# %%
async def get_all_albums(artist_id: str, *, include_groups: str | None = None, market="US"):
    offset = 0
    total = (await client.http.artist_albums(
        artist_id, limit=1, offset=0, include_groups=include_groups, market=market
    ))["total"]
    count = 0
    while count < total:
        data = await client.http.artist_albums(
            artist_id, limit=50, offset=offset, include_groups=include_groups, market=market
        )
        offset += 50
        if not data["items"]:
            break
        for album in (spotify.Album(client, item) for item in data["items"]):
            yield album
            count += 1

# %%
@dataclass(unsafe_hash=True)
class Album:
    name: str
    release_date: str
    group: str
    type: str
    id: str
    tracks: list["Track"] = field(default_factory=list, init=False, hash=False, repr=False)

@dataclass(unsafe_hash=True)
class Track:
    name: str
    album: Album = field(hash=False)
    id: str
    uri: str
    replaces: set["Track"] = field(default_factory=set, init=False, hash=False)
    replacements: set["Track"] = field(default_factory=set, init=False, hash=False)
    sorted_replacements: list["Track"] = field(default_factory=list, init=False, hash=False)


async def load_tracks() -> tuple[list[Album], list[Track]]:
    album_list = []
    track_list = []

    TAYLOR_SWIFT_ID = "06HL4z0CvFAxyc27GXpf02"
    async for album in get_all_albums(TAYLOR_SWIFT_ID, include_groups="album,single,compilation", market="US"):
        print(album.name)
        album_list.append(Album(album.name, album.release_date, album.group, album.type, album.id))

    album_list.sort(key=lambda a: a.release_date, reverse=True)

    for album in album_list:
        print(album.name)
        album.tracks = [
            Track(track["name"], album, track["id"], track["uri"])
            for track in (await client.http.album_tracks(album.id, limit=50))["items"]
        ]
        track_list.extend(album.tracks)

    with open("taylor_tracks.json", "w") as f:
        json.dump([
            {"name": album.name, "release_date": album.release_date, "id": album.id, "tracks": [{"name": track.name, "id": track.id} for track in album.tracks]}
            for album in album_list
        ], f, indent=2)

    return album_list, track_list


albums, tracks = await load_tracks()
# Out:
# Speak Now (Taylor's Version)
# Midnights (The Til Dawn Edition)
# Midnights (3am Edition)
# Midnights
# Red (Taylor's Version)
# Fearless (Taylor's Version)
# evermore (deluxe version)
# evermore
# folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]
# folklore (deluxe version)
# folklore
# Lover
# reputation
# reputation Stadium Tour Surprise Song Playlist
# 1989 (Deluxe Edition)
# 1989
# Red (Deluxe Edition)
# Red
# Speak Now World Tour Live
# Speak Now (Deluxe Edition)
# Speak Now
# Fearless Platinum Edition
# Fearless
# Live From Clear Channel Stripped 2008
# Taylor Swift
# Lavender Haze (Acoustic Version)
# Lavender Haze (Remixes)
# Lavender Haze (Felix Jaehn Remix)
# Anti-Hero (Acoustic Version)
# Anti-Hero (ILLENIUM Remix)
# Anti-Hero (Remixes)
# Anti-Hero (feat. Bleachers)
# Carolina (From The Motion Picture “Where The Crawdads Sing”)
# All Too Well (10 Minute Version) (The Short Film)
# This Love (Taylor’s Version)
# The Joker And The Queen (feat. Taylor Swift)
# Message In A Bottle (Fat Max G Remix) (Taylor’s Version)
# Christmas Tree Farm (Old Timey Version)
# All Too Well (Sad Girl Autumn Version) - Recorded at Long Pond Studios
# The More Red (Taylor’s Version) Chapter
# Safe & Sound (Taylor's Version)
# Eyes Open (Taylor's Version)
# Wildest Dreams (Taylor's Version)
# Renegade (Pop Version)
# the lakes (original version)
# willow (90's trend remix)
# The More Fearless (Taylor’s Version) Chapter
# If This Was A Movie (Taylor’s Version)
# Mr. Perfectly Fine (Taylor’s Version) (From The Vault)
# You All Over Me (feat. Maren Morris) (Taylor’s Version) (From The Vault)
# You Need To Calm Down (Clean Bandit Remix)
# Delicate (Seeb Remix)
# Delicate (Sawyr And Ryan Tedder Mix)
# Spotify Singles
# ...Ready For It? (BloodPop® Remix)
# Bad Blood
# Wildest Dreams (R3hab Remix)
# Sweeter Than Fiction
# Everything Has Changed (Remix)
# Ronan
# Today Was A Fairytale
# The Taylor Swift Holiday Collection
# Speak Now (Taylor's Version)
# Midnights (The Til Dawn Edition)
# Lavender Haze (Acoustic Version)
# Lavender Haze (Remixes)
# Lavender Haze (Felix Jaehn Remix)
# Anti-Hero (Acoustic Version)
# Anti-Hero (ILLENIUM Remix)
# Anti-Hero (Remixes)
# Anti-Hero (feat. Bleachers)
# Midnights (3am Edition)
# Midnights
# Carolina (From The Motion Picture “Where The Crawdads Sing”)
# All Too Well (10 Minute Version) (The Short Film)
# This Love (Taylor’s Version)
# The Joker And The Queen (feat. Taylor Swift)
# Message In A Bottle (Fat Max G Remix) (Taylor’s Version)
# Christmas Tree Farm (Old Timey Version)
# All Too Well (Sad Girl Autumn Version) - Recorded at Long Pond Studios
# Red (Taylor's Version)
# The More Red (Taylor’s Version) Chapter
# Safe & Sound (Taylor's Version)
# Eyes Open (Taylor's Version)
# Wildest Dreams (Taylor's Version)
# Renegade (Pop Version)
# the lakes (original version)
# willow (90's trend remix)
# Fearless (Taylor's Version)
# The More Fearless (Taylor’s Version) Chapter
# If This Was A Movie (Taylor’s Version)
# Mr. Perfectly Fine (Taylor’s Version) (From The Vault)
# You All Over Me (feat. Maren Morris) (Taylor’s Version) (From The Vault)
# evermore (deluxe version)
# evermore
# folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]
# folklore (deluxe version)
# folklore
# Lover
# You Need To Calm Down (Clean Bandit Remix)
# Delicate (Seeb Remix)
# Delicate (Sawyr And Ryan Tedder Mix)
# Spotify Singles
# ...Ready For It? (BloodPop® Remix)
# reputation
# reputation Stadium Tour Surprise Song Playlist
# Bad Blood
# Wildest Dreams (R3hab Remix)
# 1989 (Deluxe Edition)
# 1989
# Sweeter Than Fiction
# Everything Has Changed (Remix)
# Red (Deluxe Edition)
# Red
# Ronan
# Speak Now World Tour Live
# Speak Now (Deluxe Edition)
# Speak Now
# Today Was A Fairytale
# The Taylor Swift Holiday Collection
# Fearless Platinum Edition
# Fearless
# Live From Clear Channel Stripped 2008
# Taylor Swift

# %%
def normalize_name(name: str):
    return name \
        .replace("\u2019", "'") \
        .replace("SuperStar", "Superstar") \
        .replace("I Knew You Were Trouble.", "I Knew You Were Trouble")

def get_song_name(name: str):
    return name.split("(", 1)[0].strip()

for track in tracks:
    track.replaces = set()
    track.replacements = set()

for track in tracks:
    name = normalize_name(track.name)
    if "(Taylor's Version)" in name and "(From The Vault)" not in name:
        song_name = get_song_name(name)

        for stolen in tracks:
            stolen_name = normalize_name(stolen.name)
            if stolen_name.startswith(song_name) and " Version)" not in stolen_name:  # Version) also catches ATW versions
                track.replaces.add(stolen)
                stolen.replacements.add(track)
        if not track.replaces:
            print("No stolen found:", track.name, "->", song_name)


for stolen in tracks:
    song_name = normalize_name(stolen.name)
    stolen.sorted_replacements = sorted(
        stolen.replacements,
        key=lambda track: (
            song_name == get_song_name(normalize_name(track.name)),
            song_name in track.album.name,
            track.album.type == "album",
            track.name == track.album.name
        ),
        reverse=True
    )

for album in albums:
    print("\n\n\n###", album.name, end="\n\n")
    for track in album.tracks:
        print(track.name)
        for replacement in track.sorted_replacements:
            print("  ->", replacement.name, "–", replacement.album)
        if (
            not track.sorted_replacements and
            "(Taylor's Version)" not in album.name and
            album.release_date < "2019-08-20"
        ):
            print("  NO REPLACEMENTS")


replacements = {}
for stolen in tracks:
    if stolen.sorted_replacements:
        replacements[stolen.id] = {
            "__name ": stolen.name,
            "__album": stolen.album.name,
            "__album_type": stolen.album.type,
        }
        if "live" in stolen.name.lower():
            replacements[stolen.id]["is_live"] = True
        if "remix" in stolen.name.lower():
            replacements[stolen.id]["is_remix"] = True
        replacements[stolen.id]["replacements"] = [
            {
                "__name ": track.name,
                "__album": track.album.name,
                "__album_type": track.album.type,
                "id": track.id,
            }
            for track in stolen.sorted_replacements
        ]
with open("taylorsversion.json", "w") as f:
    json.dump(replacements, f, indent=2)
# Out:
# No stolen found: Message In A Bottle (Fat Max G Remix) (Taylor’s Version) -> Message In A Bottle
# No stolen found: Eyes Open (Taylor's Version) -> Eyes Open
# No stolen found: Safe & Sound (feat. Joy Williams and John Paul White) (Taylor’s Version) -> Safe & Sound
# No stolen found: Safe & Sound (feat. Joy Williams and John Paul White) (Taylor’s Version) -> Safe & Sound
# No stolen found: Eyes Open (Taylor's Version) -> Eyes Open
#
#
#
# ### Speak Now (Taylor's Version)
#
# Mine (Taylor's Version)
# Sparks Fly (Taylor’s Version)
# Back To December (Taylor's Version)
# Speak Now (Taylor's Version)
# Dear John (Taylor's Version)
# Mean (Taylor's Version)
# The Story Of Us (Taylor's Version)
# Never Grow Up (Taylor's Version)
# Enchanted (Taylor's Version)
# Better Than Revenge (Taylor's Version)
# Innocent (Taylor's Version)
# Haunted (Taylor's Version)
# Last Kiss (Taylor's Version)
# Long Live (Taylor's Version)
# Ours (Taylor’s Version)
# Superman (Taylor’s Version)
# Electric Touch (feat. Fall Out Boy) (Taylor’s Version) (From The Vault)
# When Emma Falls in Love (Taylor’s Version) (From The Vault)
# I Can See You (Taylor’s Version) (From The Vault)
# Castles Crumbling (feat. Hayley Williams) (Taylor’s Version) (From The Vault)
# Foolish One (Taylor’s Version) (From The Vault)
# Timeless (Taylor’s Version) (From The Vault)
#
#
#
# ### Midnights (The Til Dawn Edition)
#
# Lavender Haze
# Maroon
# Anti-Hero
# Snow On The Beach (feat. Lana Del Rey)
# You're On Your Own, Kid
# Midnight Rain
# Question...?
# Vigilante Shit
# Bejeweled
# Labyrinth
# Karma
# Sweet Nothing
# Mastermind
# The Great War
# Bigger Than The Whole Sky
# Paris
# High Infidelity
# Glitch
# Would've, Could've, Should've
# Dear Reader
# Hits Different
# Snow On The Beach (feat. More Lana Del Rey)
# Karma (feat. Ice Spice)
#
#
#
# ### Lavender Haze (Acoustic Version)
#
# Lavender Haze - Acoustic Version
#
#
#
# ### Lavender Haze (Remixes)
#
# Lavender Haze - Tensnake Remix
# Lavender Haze - Snakehips Remix
# Lavender Haze - Jungle Remix
# Lavender Haze - Felix Jaehn Remix
# Lavender Haze
#
#
#
# ### Lavender Haze (Felix Jaehn Remix)
#
# Lavender Haze - Felix Jaehn Remix
#
#
#
# ### Anti-Hero (Acoustic Version)
#
# Anti-Hero - Acoustic Version
#
#
#
# ### Anti-Hero (ILLENIUM Remix)
#
# Anti-Hero - ILLENIUM Remix
#
#
#
# ### Anti-Hero (Remixes)
#
# Anti-Hero (feat. Bleachers)
# Anti-Hero - Roosevelt Remix
# Anti-Hero - Kungs Remix
# Anti-Hero - Jayda G Remix
# Anti-Hero
#
#
#
# ### Anti-Hero (feat. Bleachers)
#
# Anti-Hero (feat. Bleachers)
# Anti-Hero
#
#
#
# ### Midnights (3am Edition)
#
# Lavender Haze
# Maroon
# Anti-Hero
# Snow On The Beach (feat. Lana Del Rey)
# You're On Your Own, Kid
# Midnight Rain
# Question...?
# Vigilante Shit
# Bejeweled
# Labyrinth
# Karma
# Sweet Nothing
# Mastermind
# The Great War
# Bigger Than The Whole Sky
# Paris
# High Infidelity
# Glitch
# Would've, Could've, Should've
# Dear Reader
#
#
#
# ### Midnights
#
# Lavender Haze
# Maroon
# Anti-Hero
# Snow On The Beach (feat. Lana Del Rey)
# You're On Your Own, Kid
# Midnight Rain
# Question...?
# Vigilante Shit
# Bejeweled
# Labyrinth
# Karma
# Sweet Nothing
# Mastermind
#
#
#
# ### Carolina (From The Motion Picture “Where The Crawdads Sing”)
#
# Carolina - From The Motion Picture “Where The Crawdads Sing”
# Carolina - "Where The Crawdads Sing" - Video Edition
#
#
#
# ### All Too Well (10 Minute Version) (The Short Film)
#
# All Too Well (10 Minute Version) (The Short Film)
#
#
#
# ### This Love (Taylor’s Version)
#
# This Love (Taylor’s Version)
# Wildest Dreams (Taylor's Version)
#
#
#
# ### The Joker And The Queen (feat. Taylor Swift)
#
# The Joker And The Queen (feat. Taylor Swift)
#
#
#
# ### Message In A Bottle (Fat Max G Remix) (Taylor’s Version)
#
# Message In A Bottle (Fat Max G Remix) (Taylor’s Version)
# Message In A Bottle (Taylor's Version) (From The Vault)
#
#
#
# ### Christmas Tree Farm (Old Timey Version)
#
# Christmas Tree Farm (Old Timey Version)
#
#
#
# ### All Too Well (Sad Girl Autumn Version) - Recorded at Long Pond Studios
#
# All Too Well (Sad Girl Autumn Version) - Recorded at Long Pond Studios
#
#
#
# ### Red (Taylor's Version)
#
# State Of Grace (Taylor's Version)
# Red (Taylor's Version)
# Treacherous (Taylor's Version)
# I Knew You Were Trouble (Taylor's Version)
# All Too Well (Taylor's Version)
# 22 (Taylor's Version)
# I Almost Do (Taylor's Version)
# We Are Never Ever Getting Back Together (Taylor's Version)
# Stay Stay Stay (Taylor's Version)
# The Last Time (feat. Gary Lightbody of Snow Patrol) (Taylor’s Version)
# Holy Ground (Taylor's Version)
# Sad Beautiful Tragic (Taylor's Version)
# The Lucky One (Taylor's Version)
# Everything Has Changed (feat. Ed Sheeran) (Taylor’s Version)
# Starlight (Taylor's Version)
# Begin Again (Taylor's Version)
# The Moment I Knew (Taylor's Version)
# Come Back...Be Here (Taylor's Version)
# Girl At Home (Taylor's Version)
# State Of Grace (Acoustic Version) (Taylor's Version)
# Ronan (Taylor's Version)
# Better Man (Taylor's Version) (From The Vault)
# Nothing New (feat. Phoebe Bridgers) (Taylor’s Version) (From The Vault)
# Babe (Taylor's Version) (From The Vault)
# Message In A Bottle (Taylor's Version) (From The Vault)
# I Bet You Think About Me (feat. Chris Stapleton) (Taylor’s Version) (From The Vault)
# Forever Winter (Taylor's Version) (From The Vault)
# Run (feat. Ed Sheeran) (Taylor’s Version) (From The Vault)
# The Very First Night (Taylor's Version) (From The Vault)
# All Too Well (10 Minute Version) (Taylor's Version) (From The Vault)
#
#
#
# ### The More Red (Taylor’s Version) Chapter
#
# I Knew You Were Trouble (Taylor's Version)
# 22 (Taylor's Version)
# We Are Never Ever Getting Back Together (Taylor's Version)
# All Too Well (10 Minute Version) (Taylor's Version) (From The Vault)
# Eyes Open (Taylor's Version)
# Safe & Sound (feat. Joy Williams and John Paul White) (Taylor’s Version)
#
#
#
# ### Safe & Sound (Taylor's Version)
#
# Safe & Sound (feat. Joy Williams and John Paul White) (Taylor’s Version)
#
#
#
# ### Eyes Open (Taylor's Version)
#
# Eyes Open (Taylor's Version)
#
#
#
# ### Wildest Dreams (Taylor's Version)
#
# Wildest Dreams (Taylor's Version)
#
#
#
# ### Renegade (Pop Version)
#
# Renegade - Pop Version
#
#
#
# ### the lakes (original version)
#
# the lakes - original version
#
#
#
# ### willow (90's trend remix)
#
# willow - 90's trend remix
#
#
#
# ### Fearless (Taylor's Version)
#
# Fearless (Taylor’s Version)
# Fifteen (Taylor’s Version)
# Love Story (Taylor’s Version)
# Hey Stephen (Taylor’s Version)
# White Horse (Taylor’s Version)
# You Belong With Me (Taylor’s Version)
# Breathe (feat. Colbie Caillat) (Taylor’s Version)
# Tell Me Why (Taylor’s Version)
# You’re Not Sorry (Taylor’s Version)
# The Way I Loved You (Taylor’s Version)
# Forever & Always (Taylor’s Version)
# The Best Day (Taylor’s Version)
# Change (Taylor’s Version)
# Jump Then Fall (Taylor’s Version)
# Untouchable (Taylor’s Version)
# Forever & Always (Piano Version) (Taylor’s Version)
# Come In With The Rain (Taylor’s Version)
# Superstar (Taylor’s Version)
# The Other Side Of The Door (Taylor’s Version)
# Today Was A Fairytale (Taylor’s Version)
# You All Over Me (feat. Maren Morris) (Taylor’s Version) (From The Vault)
# Mr. Perfectly Fine (Taylor’s Version) (From The Vault)
# We Were Happy (Taylor’s Version) (From The Vault)
# That’s When (feat. Keith Urban) (Taylor’s Version) (From The Vault)
# Don’t You (Taylor’s Version) (From The Vault)
# Bye Bye Baby (Taylor’s Version) (From The Vault)
#
#
#
# ### The More Fearless (Taylor’s Version) Chapter
#
# Fearless (Taylor’s Version)
# Love Story (Taylor’s Version)
# White Horse (Taylor’s Version)
# You Belong With Me (Taylor’s Version)
# If This Was A Movie (Taylor’s Version)
#
#
#
# ### If This Was A Movie (Taylor’s Version)
#
# If This Was A Movie (Taylor’s Version)
#
#
#
# ### Mr. Perfectly Fine (Taylor’s Version) (From The Vault)
#
# Mr. Perfectly Fine (Taylor’s Version) (From The Vault)
#
#
#
# ### You All Over Me (feat. Maren Morris) (Taylor’s Version) (From The Vault)
#
# You All Over Me (feat. Maren Morris) (Taylor’s Version) (From The Vault)
#
#
#
# ### evermore (deluxe version)
#
# willow
# champagne problems
# gold rush
# ‘tis the damn season
# tolerate it
# no body, no crime (feat. HAIM)
# happiness
# dorothea
# coney island (feat. The National)
# ivy
# cowboy like me
# long story short
# marjorie
# closure
# evermore (feat. Bon Iver)
# right where you left me - bonus track
# it’s time to go - bonus track
#
#
#
# ### evermore
#
# willow
# champagne problems
# gold rush
# ‘tis the damn season
# tolerate it
# no body, no crime (feat. HAIM)
# happiness
# dorothea
# coney island (feat. The National)
# ivy
# cowboy like me
# long story short
# marjorie
# closure
# evermore (feat. Bon Iver)
#
#
#
# ### folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]
#
# the 1
# cardigan
# the last great american dynasty
# exile (feat. Bon Iver)
# my tears ricochet
# mirrorball
# seven
# august
# this is me trying
# illicit affairs
# invisible string
# mad woman
# epiphany
# betty
# peace
# hoax
# the lakes - bonus track
# the 1 - the long pond studio sessions
# cardigan - the long pond studio sessions
# the last great american dynasty - the long pond studio sessions
# exile (feat. Bon Iver) - the long pond studio sessions
# my tears ricochet - the long pond studio sessions
# mirrorball - the long pond studio sessions
# seven - the long pond studio sessions
# august - the long pond studio sessions
# this is me trying - the long pond studio sessions
# illicit affairs - the long pond studio sessions
# invisible string - the long pond studio sessions
# mad woman - the long pond studio sessions
# epiphany - the long pond studio sessions
# betty - the long pond studio sessions
# peace - the long pond studio sessions
# hoax - the long pond studio sessions
# the lakes - the long pond studio sessions
#
#
#
# ### folklore (deluxe version)
#
# the 1
# cardigan
# the last great american dynasty
# exile (feat. Bon Iver)
# my tears ricochet
# mirrorball
# seven
# august
# this is me trying
# illicit affairs
# invisible string
# mad woman
# epiphany
# betty
# peace
# hoax
# the lakes - bonus track
#
#
#
# ### folklore
#
# the 1
# cardigan
# the last great american dynasty
# exile (feat. Bon Iver)
# my tears ricochet
# mirrorball
# seven
# august
# this is me trying
# illicit affairs
# invisible string
# mad woman
# epiphany
# betty
# peace
# hoax
#
#
#
# ### Lover
#
# I Forgot That You Existed
# Cruel Summer
# Lover
# The Man
# The Archer
# I Think He Knows
# Miss Americana & The Heartbreak Prince
# Paper Rings
# Cornelia Street
# Death By A Thousand Cuts
# London Boy
# Soon You’ll Get Better (feat. The Chicks)
# False God
# You Need To Calm Down
# Afterglow
# ME! (feat. Brendon Urie of Panic! At The Disco)
# It’s Nice To Have A Friend
# Daylight
#
#
#
# ### You Need To Calm Down (Clean Bandit Remix)
#
# You Need To Calm Down - Clean Bandit Remix
#
#
#
# ### Delicate (Seeb Remix)
#
# Delicate - Seeb Remix
#   NO REPLACEMENTS
#
#
#
# ### Delicate (Sawyr And Ryan Tedder Mix)
#
# Delicate - Sawyr And Ryan Tedder Mix
#   NO REPLACEMENTS
#
#
#
# ### Spotify Singles
#
# Delicate - Recorded at The Tracking Room Nashville
#   NO REPLACEMENTS
# September - Recorded at The Tracking Room Nashville
#   NO REPLACEMENTS
#
#
#
# ### ...Ready For It? (BloodPop® Remix)
#
# ...Ready For It? - BloodPop® Remix
#   NO REPLACEMENTS
#
#
#
# ### reputation
#
# ...Ready For It?
#   NO REPLACEMENTS
# End Game
#   NO REPLACEMENTS
# I Did Something Bad
#   NO REPLACEMENTS
# Don’t Blame Me
#   NO REPLACEMENTS
# Delicate
#   NO REPLACEMENTS
# Look What You Made Me Do
#   NO REPLACEMENTS
# So It Goes...
#   NO REPLACEMENTS
# Gorgeous
#   NO REPLACEMENTS
# Getaway Car
#   NO REPLACEMENTS
# King Of My Heart
#   NO REPLACEMENTS
# Dancing With Our Hands Tied
#   NO REPLACEMENTS
# Dress
#   NO REPLACEMENTS
# This Is Why We Can't Have Nice Things
#   NO REPLACEMENTS
# Call It What You Want
#   NO REPLACEMENTS
# New Year’s Day
#   NO REPLACEMENTS
#
#
#
# ### reputation Stadium Tour Surprise Song Playlist
#
# All Too Well
#   -> All Too Well (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Wildest Dreams
#   -> Wildest Dreams (Taylor's Version) – Album(name="Wildest Dreams (Taylor's Version)", release_date='2021-09-17', group='single', type='single', id='5hxKw2PurC0i1VVJMAntDU')
#   -> Wildest Dreams (Taylor's Version) – Album(name='This Love (Taylor’s Version)', release_date='2022-05-06', group='single', type='single', id='3In1CblWZswwun5MhOa10y')
# The Best Day
#   -> The Best Day (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Red
#   -> Red (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Holy Ground
#   -> Holy Ground (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Teardrops On My Guitar - Radio Single Remix
#   NO REPLACEMENTS
# Our Song
#   NO REPLACEMENTS
# 22
#   -> 22 (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#   -> 22 (Taylor's Version) – Album(name='The More Red (Taylor’s Version) Chapter', release_date='2021-11-12', group='single', type='single', id='1qEs8XpGGduMUF7jfAs5l3')
# I Knew You Were Trouble.
#   -> I Knew You Were Trouble (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#   -> I Knew You Were Trouble (Taylor's Version) – Album(name='The More Red (Taylor’s Version) Chapter', release_date='2021-11-12', group='single', type='single', id='1qEs8XpGGduMUF7jfAs5l3')
# I Don’t Wanna Live Forever (Fifty Shades Darker)
#   NO REPLACEMENTS
# Mean
#   -> Mean (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# How You Get The Girl
#   NO REPLACEMENTS
# So It Goes...
#   NO REPLACEMENTS
# Fifteen
#   -> Fifteen (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Mine
#   -> Mine (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Sparks Fly
#   -> Sparks Fly (Taylor’s Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# State Of Grace
#   -> State Of Grace (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#   -> State Of Grace (Acoustic Version) (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Haunted
#   -> Haunted (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Never Grow Up
#   -> Never Grow Up (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Treacherous
#   -> Treacherous (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Babe
#   NO REPLACEMENTS
# Welcome To New York
#   NO REPLACEMENTS
# Fearless
#   -> Fearless (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> Fearless (Taylor’s Version) – Album(name='The More Fearless (Taylor’s Version) Chapter', release_date='2021-04-09', group='single', type='single', id='6MMVrrxnNgGKg04ze1Pemw')
# Enchanted
#   -> Enchanted (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Change
#   -> Change (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Ours
#   -> Ours (Taylor’s Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Out Of The Woods
#   NO REPLACEMENTS
# Come Back...Be Here
#   -> Come Back...Be Here (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# A Place in this World
#   NO REPLACEMENTS
# This Love
#   -> This Love (Taylor’s Version) – Album(name='This Love (Taylor’s Version)', release_date='2022-05-06', group='single', type='single', id='3In1CblWZswwun5MhOa10y')
# The Lucky One
#   -> The Lucky One (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Invisible
#   NO REPLACEMENTS
# Breathe
#   -> Breathe (feat. Colbie Caillat) (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Better Man
#   NO REPLACEMENTS
# Jump Then Fall
#   -> Jump Then Fall (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Begin Again
#   -> Begin Again (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Tied Together with a Smile
#   NO REPLACEMENTS
# The Story Of Us
#   -> The Story Of Us (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Forever & Always
#   -> Forever & Always (Piano Version) (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> Forever & Always (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Hey Stephen
#   -> Hey Stephen (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Speak Now
#   -> Speak Now (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Wonderland
#   NO REPLACEMENTS
# White Horse
#   -> White Horse (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> White Horse (Taylor’s Version) – Album(name='The More Fearless (Taylor’s Version) Chapter', release_date='2021-04-09', group='single', type='single', id='6MMVrrxnNgGKg04ze1Pemw')
# I'm Only Me When I'm With You
#   NO REPLACEMENTS
# Starlight
#   -> Starlight (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# I Know Places
#   NO REPLACEMENTS
#
#
#
# ### Bad Blood
#
# Bad Blood
#   NO REPLACEMENTS
#
#
#
# ### Wildest Dreams (R3hab Remix)
#
# Wildest Dreams - R3hab Remix
#   -> Wildest Dreams (Taylor's Version) – Album(name="Wildest Dreams (Taylor's Version)", release_date='2021-09-17', group='single', type='single', id='5hxKw2PurC0i1VVJMAntDU')
#   -> Wildest Dreams (Taylor's Version) – Album(name='This Love (Taylor’s Version)', release_date='2022-05-06', group='single', type='single', id='3In1CblWZswwun5MhOa10y')
#
#
#
# ### 1989 (Deluxe Edition)
#
# Welcome To New York
#   NO REPLACEMENTS
# Blank Space
#   NO REPLACEMENTS
# Style
#   NO REPLACEMENTS
# Out Of The Woods
#   NO REPLACEMENTS
# All You Had To Do Was Stay
#   NO REPLACEMENTS
# Shake It Off
#   NO REPLACEMENTS
# I Wish You Would
#   NO REPLACEMENTS
# Bad Blood
#   NO REPLACEMENTS
# Wildest Dreams
#   -> Wildest Dreams (Taylor's Version) – Album(name="Wildest Dreams (Taylor's Version)", release_date='2021-09-17', group='single', type='single', id='5hxKw2PurC0i1VVJMAntDU')
#   -> Wildest Dreams (Taylor's Version) – Album(name='This Love (Taylor’s Version)', release_date='2022-05-06', group='single', type='single', id='3In1CblWZswwun5MhOa10y')
# How You Get The Girl
#   NO REPLACEMENTS
# This Love
#   -> This Love (Taylor’s Version) – Album(name='This Love (Taylor’s Version)', release_date='2022-05-06', group='single', type='single', id='3In1CblWZswwun5MhOa10y')
# I Know Places
#   NO REPLACEMENTS
# Clean
#   NO REPLACEMENTS
# Wonderland
#   NO REPLACEMENTS
# You Are In Love
#   NO REPLACEMENTS
# New Romantics
#   NO REPLACEMENTS
# I Know Places - Voice Memo
#   NO REPLACEMENTS
# I Wish You Would - Voice Memo
#   NO REPLACEMENTS
# Blank Space - Voice Memo
#   NO REPLACEMENTS
#
#
#
# ### 1989
#
# Welcome To New York
#   NO REPLACEMENTS
# Blank Space
#   NO REPLACEMENTS
# Style
#   NO REPLACEMENTS
# Out Of The Woods
#   NO REPLACEMENTS
# All You Had To Do Was Stay
#   NO REPLACEMENTS
# Shake It Off
#   NO REPLACEMENTS
# I Wish You Would
#   NO REPLACEMENTS
# Bad Blood
#   NO REPLACEMENTS
# Wildest Dreams
#   -> Wildest Dreams (Taylor's Version) – Album(name="Wildest Dreams (Taylor's Version)", release_date='2021-09-17', group='single', type='single', id='5hxKw2PurC0i1VVJMAntDU')
#   -> Wildest Dreams (Taylor's Version) – Album(name='This Love (Taylor’s Version)', release_date='2022-05-06', group='single', type='single', id='3In1CblWZswwun5MhOa10y')
# How You Get The Girl
#   NO REPLACEMENTS
# This Love
#   -> This Love (Taylor’s Version) – Album(name='This Love (Taylor’s Version)', release_date='2022-05-06', group='single', type='single', id='3In1CblWZswwun5MhOa10y')
# I Know Places
#   NO REPLACEMENTS
# Clean
#   NO REPLACEMENTS
#
#
#
# ### Sweeter Than Fiction
#
# Sweeter Than Fiction - From "One Chance" Soundtrack
#   NO REPLACEMENTS
#
#
#
# ### Everything Has Changed (Remix)
#
# Everything Has Changed - Remix
#   -> Everything Has Changed (feat. Ed Sheeran) (Taylor’s Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#
#
#
# ### Red (Deluxe Edition)
#
# State Of Grace
#   -> State Of Grace (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#   -> State Of Grace (Acoustic Version) (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Red
#   -> Red (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Treacherous
#   -> Treacherous (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# I Knew You Were Trouble.
#   -> I Knew You Were Trouble (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#   -> I Knew You Were Trouble (Taylor's Version) – Album(name='The More Red (Taylor’s Version) Chapter', release_date='2021-11-12', group='single', type='single', id='1qEs8XpGGduMUF7jfAs5l3')
# All Too Well
#   -> All Too Well (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# 22
#   -> 22 (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#   -> 22 (Taylor's Version) – Album(name='The More Red (Taylor’s Version) Chapter', release_date='2021-11-12', group='single', type='single', id='1qEs8XpGGduMUF7jfAs5l3')
# I Almost Do
#   -> I Almost Do (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# We Are Never Ever Getting Back Together
#   -> We Are Never Ever Getting Back Together (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#   -> We Are Never Ever Getting Back Together (Taylor's Version) – Album(name='The More Red (Taylor’s Version) Chapter', release_date='2021-11-12', group='single', type='single', id='1qEs8XpGGduMUF7jfAs5l3')
# Stay Stay Stay
#   -> Stay Stay Stay (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# The Last Time
#   -> The Last Time (feat. Gary Lightbody of Snow Patrol) (Taylor’s Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Holy Ground
#   -> Holy Ground (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Sad Beautiful Tragic
#   -> Sad Beautiful Tragic (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# The Lucky One
#   -> The Lucky One (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Everything Has Changed
#   -> Everything Has Changed (feat. Ed Sheeran) (Taylor’s Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Starlight
#   -> Starlight (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Begin Again
#   -> Begin Again (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# The Moment I Knew
#   -> The Moment I Knew (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Come Back...Be Here
#   -> Come Back...Be Here (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Girl At Home
#   -> Girl At Home (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Treacherous - Original Demo Recording
#   -> Treacherous (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Red - Original Demo Recording
#   -> Red (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# State Of Grace - Acoustic
#   -> State Of Grace (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#   -> State Of Grace (Acoustic Version) (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#
#
#
# ### Red
#
# State Of Grace
#   -> State Of Grace (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#   -> State Of Grace (Acoustic Version) (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Red
#   -> Red (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Treacherous
#   -> Treacherous (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# I Knew You Were Trouble.
#   -> I Knew You Were Trouble (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#   -> I Knew You Were Trouble (Taylor's Version) – Album(name='The More Red (Taylor’s Version) Chapter', release_date='2021-11-12', group='single', type='single', id='1qEs8XpGGduMUF7jfAs5l3')
# All Too Well
#   -> All Too Well (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# 22
#   -> 22 (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#   -> 22 (Taylor's Version) – Album(name='The More Red (Taylor’s Version) Chapter', release_date='2021-11-12', group='single', type='single', id='1qEs8XpGGduMUF7jfAs5l3')
# I Almost Do
#   -> I Almost Do (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# We Are Never Ever Getting Back Together
#   -> We Are Never Ever Getting Back Together (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#   -> We Are Never Ever Getting Back Together (Taylor's Version) – Album(name='The More Red (Taylor’s Version) Chapter', release_date='2021-11-12', group='single', type='single', id='1qEs8XpGGduMUF7jfAs5l3')
# Stay Stay Stay
#   -> Stay Stay Stay (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# The Last Time
#   -> The Last Time (feat. Gary Lightbody of Snow Patrol) (Taylor’s Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Holy Ground
#   -> Holy Ground (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Sad Beautiful Tragic
#   -> Sad Beautiful Tragic (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# The Lucky One
#   -> The Lucky One (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Everything Has Changed
#   -> Everything Has Changed (feat. Ed Sheeran) (Taylor’s Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Starlight
#   -> Starlight (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
# Begin Again
#   -> Begin Again (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#
#
#
# ### Ronan
#
# Ronan
#   -> Ronan (Taylor's Version) – Album(name="Red (Taylor's Version)", release_date='2021-11-12', group='album', type='album', id='6kZ42qRrzov54LcAk4onW9')
#
#
#
# ### Speak Now World Tour Live
#
# Sparks Fly - Live/2011
#   -> Sparks Fly (Taylor’s Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Mine - Live/2011
#   -> Mine (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# The Story Of Us - Live
#   -> The Story Of Us (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Mean - Live/2011
#   -> Mean (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Ours - Live/2011
#   -> Ours (Taylor’s Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Back To December/Apologize/You're Not Sorry - Live/2011/Medley
#   -> Back To December (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Better Than Revenge - Live/2011
#   -> Better Than Revenge (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Speak Now - Live/2011
#   -> Speak Now (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Last Kiss - Live/2011
#   -> Last Kiss (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Drops Of Jupiter - Live/2011
#   NO REPLACEMENTS
# Bette Davis Eyes - Live/2011
#   NO REPLACEMENTS
# I Want You Back - Live/2011
#   NO REPLACEMENTS
# Dear John - Live/2011
#   -> Dear John (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Enchanted - Live/2011
#   -> Enchanted (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Haunted - Live/2011
#   -> Haunted (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Long Live - Live/2011
#   -> Long Live (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
#
#
#
# ### Speak Now (Deluxe Edition)
#
# Mine
#   -> Mine (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Sparks Fly
#   -> Sparks Fly (Taylor’s Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Back To December
#   -> Back To December (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Speak Now
#   -> Speak Now (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Dear John
#   -> Dear John (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Mean
#   -> Mean (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# The Story Of Us
#   -> The Story Of Us (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Never Grow Up
#   -> Never Grow Up (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Enchanted
#   -> Enchanted (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Better Than Revenge
#   -> Better Than Revenge (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Innocent
#   -> Innocent (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Haunted
#   -> Haunted (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Last Kiss
#   -> Last Kiss (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Long Live
#   -> Long Live (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Ours
#   -> Ours (Taylor’s Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# If This Was A Movie
#   -> If This Was A Movie (Taylor’s Version) – Album(name='If This Was A Movie (Taylor’s Version)', release_date='2021-04-09', group='single', type='single', id='6IZm7NfvWyXp952VF36Z5F')
#   -> If This Was A Movie (Taylor’s Version) – Album(name='The More Fearless (Taylor’s Version) Chapter', release_date='2021-04-09', group='single', type='single', id='6MMVrrxnNgGKg04ze1Pemw')
# Superman
#   -> Superman (Taylor’s Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Back To December - Acoustic
#   -> Back To December (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Haunted - Acoustic Version
#   -> Haunted (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Mine - POP Mix
#   -> Mine (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
#
#
#
# ### Speak Now
#
# Mine
#   -> Mine (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Sparks Fly
#   -> Sparks Fly (Taylor’s Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Back To December
#   -> Back To December (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Speak Now
#   -> Speak Now (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Dear John
#   -> Dear John (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Mean
#   -> Mean (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# The Story Of Us
#   -> The Story Of Us (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Never Grow Up
#   -> Never Grow Up (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Enchanted
#   -> Enchanted (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Better Than Revenge
#   -> Better Than Revenge (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Innocent
#   -> Innocent (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Haunted
#   -> Haunted (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Last Kiss
#   -> Last Kiss (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
# Long Live
#   -> Long Live (Taylor's Version) – Album(name="Speak Now (Taylor's Version)", release_date='2023-07-07', group='album', type='album', id='5AEDGbliTTfjOB8TSm1sxt')
#
#
#
# ### Today Was A Fairytale
#
# Today Was A Fairytale - US Version
#   -> Today Was A Fairytale (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#
#
#
# ### The Taylor Swift Holiday Collection
#
# Last Christmas
#   NO REPLACEMENTS
# Christmases When You Were Mine
#   NO REPLACEMENTS
# Santa Baby
#   NO REPLACEMENTS
# Silent Night
#   NO REPLACEMENTS
# Christmas Must Be Something More
#   NO REPLACEMENTS
# White Christmas
#   NO REPLACEMENTS
#
#
#
# ### Fearless Platinum Edition
#
# Jump Then Fall
#   -> Jump Then Fall (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Untouchable
#   -> Untouchable (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Forever & Always - Piano Version
#   -> Forever & Always (Piano Version) (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> Forever & Always (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Come In With The Rain
#   -> Come In With The Rain (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# SuperStar
#   -> Superstar (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# The Other Side Of The Door
#   -> The Other Side Of The Door (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Fearless
#   -> Fearless (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> Fearless (Taylor’s Version) – Album(name='The More Fearless (Taylor’s Version) Chapter', release_date='2021-04-09', group='single', type='single', id='6MMVrrxnNgGKg04ze1Pemw')
# Fifteen
#   -> Fifteen (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Love Story
#   -> Love Story (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> Love Story (Taylor’s Version) – Album(name='The More Fearless (Taylor’s Version) Chapter', release_date='2021-04-09', group='single', type='single', id='6MMVrrxnNgGKg04ze1Pemw')
# Hey Stephen
#   -> Hey Stephen (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# White Horse
#   -> White Horse (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> White Horse (Taylor’s Version) – Album(name='The More Fearless (Taylor’s Version) Chapter', release_date='2021-04-09', group='single', type='single', id='6MMVrrxnNgGKg04ze1Pemw')
# You Belong With Me
#   -> You Belong With Me (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> You Belong With Me (Taylor’s Version) – Album(name='The More Fearless (Taylor’s Version) Chapter', release_date='2021-04-09', group='single', type='single', id='6MMVrrxnNgGKg04ze1Pemw')
# Breathe
#   -> Breathe (feat. Colbie Caillat) (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Tell Me Why
#   -> Tell Me Why (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# You're Not Sorry
#   -> You’re Not Sorry (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# The Way I Loved You
#   -> The Way I Loved You (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Forever & Always
#   -> Forever & Always (Piano Version) (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> Forever & Always (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# The Best Day
#   -> The Best Day (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Change
#   -> Change (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#
#
#
# ### Fearless
#
# Fearless
#   -> Fearless (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> Fearless (Taylor’s Version) – Album(name='The More Fearless (Taylor’s Version) Chapter', release_date='2021-04-09', group='single', type='single', id='6MMVrrxnNgGKg04ze1Pemw')
# Fifteen
#   -> Fifteen (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Love Story
#   -> Love Story (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> Love Story (Taylor’s Version) – Album(name='The More Fearless (Taylor’s Version) Chapter', release_date='2021-04-09', group='single', type='single', id='6MMVrrxnNgGKg04ze1Pemw')
# Hey Stephen
#   -> Hey Stephen (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# White Horse
#   -> White Horse (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> White Horse (Taylor’s Version) – Album(name='The More Fearless (Taylor’s Version) Chapter', release_date='2021-04-09', group='single', type='single', id='6MMVrrxnNgGKg04ze1Pemw')
# You Belong With Me
#   -> You Belong With Me (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> You Belong With Me (Taylor’s Version) – Album(name='The More Fearless (Taylor’s Version) Chapter', release_date='2021-04-09', group='single', type='single', id='6MMVrrxnNgGKg04ze1Pemw')
# Breathe
#   -> Breathe (feat. Colbie Caillat) (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Tell Me Why
#   -> Tell Me Why (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# You're Not Sorry
#   -> You’re Not Sorry (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# The Way I Loved You
#   -> The Way I Loved You (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Forever & Always
#   -> Forever & Always (Piano Version) (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> Forever & Always (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# The Best Day
#   -> The Best Day (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Change
#   -> Change (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#
#
#
# ### Live From Clear Channel Stripped 2008
#
# Love Story - Live From Clear Channel Stripped 2008
#   -> Love Story (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> Love Story (Taylor’s Version) – Album(name='The More Fearless (Taylor’s Version) Chapter', release_date='2021-04-09', group='single', type='single', id='6MMVrrxnNgGKg04ze1Pemw')
# Fearless - Live From Clear Channel Stripped 2008
#   -> Fearless (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#   -> Fearless (Taylor’s Version) – Album(name='The More Fearless (Taylor’s Version) Chapter', release_date='2021-04-09', group='single', type='single', id='6MMVrrxnNgGKg04ze1Pemw')
# Beautiful Eyes - Live From Clear Channel Stripped 2008
#   NO REPLACEMENTS
# Untouchable - Live From Clear Channel Stripped 2008
#   -> Untouchable (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
# Teardrops On My Guitar - Live From Clear Channel Stripped 2008
#   NO REPLACEMENTS
# Picture To Burn - Live From Clear Channel Stripped 2008
#   NO REPLACEMENTS
# Should've Said No - Live From Clear Channel Stripped 2008
#   NO REPLACEMENTS
# Change - Live From Clear Channel Stripped 2008
#   -> Change (Taylor’s Version) – Album(name="Fearless (Taylor's Version)", release_date='2021-04-09', group='album', type='album', id='4hDok0OAJd57SGIT8xuWJH')
#
#
#
# ### Taylor Swift
#
# Tim McGraw
#   NO REPLACEMENTS
# Picture To Burn
#   NO REPLACEMENTS
# Teardrops On My Guitar - Radio Single Remix
#   NO REPLACEMENTS
# A Place in this World
#   NO REPLACEMENTS
# Cold As You
#   NO REPLACEMENTS
# The Outside
#   NO REPLACEMENTS
# Tied Together with a Smile
#   NO REPLACEMENTS
# Stay Beautiful
#   NO REPLACEMENTS
# Should've Said No
#   NO REPLACEMENTS
# Mary's Song (Oh My My My)
#   NO REPLACEMENTS
# Our Song
#   NO REPLACEMENTS
# I'm Only Me When I'm With You
#   NO REPLACEMENTS
# Invisible
#   NO REPLACEMENTS
# A Perfectly Good Heart
#   NO REPLACEMENTS
# Teardrops on My Guitar - Pop Version
#   NO REPLACEMENTS
